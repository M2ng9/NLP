# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.instagram.barcelona',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=100, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_threads = pd.DataFrame(np.array(result),columns=['review'])

df_threads = df_threads.join(pd.DataFrame(df_threads.pop('review').tolist()))

df_threads.head()
# Out:
#                                reviewId                userName  \
# 0  48989521-b121-483f-b396-d431d8db5967                Saska RF
# 1  7ccb4c75-a3ae-469e-9f64-5876cf5e1500  Muhammad Husni Mubarok
# 2  9e715004-f297-4356-8a40-9f59a0f0f5be          VleezyGaming23
# 3  796ddcb0-b9d6-4abb-8939-44b7081523b0      Dicky Arya Saputra
# 4  f8f0473e-9dec-43f3-b413-bd5f4aacc4be          Dardiri Dardak
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Aku menemukan 2 bug. Yang pertama saat unggah ...      2           1648
# 1  Permulaan bagus ada saingan aplikasi burung. N...      5            876
# 2  Sedikit saran beberapa fitur buat aplikasi ini...      4            790
# 3  Aplikasi udah baik. Namun, saya menemukan bug ...      3            564
# 4  pengalaman harii kedua setelah unduh threads, ...      4            319
#
#   reviewCreatedVersion                  at replyContent repliedAt  \
# 0       289.0.0.77.109 2023-07-07 13:16:34         None      None
# 1       289.0.0.77.109 2023-07-06 20:40:14         None      None
# 2       289.0.0.77.109 2023-07-08 19:45:54         None      None
# 3       289.0.0.77.109 2023-07-06 19:08:50         None      None
# 4       289.0.0.77.109 2023-07-11 09:45:43         None      None
#
#        appVersion
# 0  289.0.0.77.109
# 1  289.0.0.77.109
# 2  289.0.0.77.109
# 3  289.0.0.77.109
# 4  289.0.0.77.109

# %%
len(df_threads.index) #count the number of data we got
# Out:
# 100

# %%
df_threads[['userName', 'score','at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#                  userName  score                  at  \
# 0                Saska RF      2 2023-07-07 13:16:34
# 1  Muhammad Husni Mubarok      5 2023-07-06 20:40:14
# 2          VleezyGaming23      4 2023-07-08 19:45:54
# 3      Dicky Arya Saputra      3 2023-07-06 19:08:50
# 4          Dardiri Dardak      4 2023-07-11 09:45:43
#
#                                              content
# 0  Aku menemukan 2 bug. Yang pertama saat unggah ...
# 1  Permulaan bagus ada saingan aplikasi burung. N...
# 2  Sedikit saran beberapa fitur buat aplikasi ini...
# 3  Aplikasi udah baik. Namun, saya menemukan bug ...
# 4  pengalaman harii kedua setelah unduh threads, ...

# %%
sorted_df = df_threads.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#                                 reviewId           userName  \
# 20  1bef2a25-9b58-429d-be5b-ea864f1343b3  Devan Febriansyah
# 19  a8484922-c2ba-45fa-9dff-40713aa99060  Alga Wahyu Aditya
# 15  d7e10b2e-29e6-4c6a-9a1f-6519c44ff8ad          Naseru 12
# 14  11cb243c-55a6-4f2a-8ffd-666b47e9de93   Santi Yunitasari
# 40  52b865fc-9ebd-447b-a228-034df90ef5f4       Hadi Santoso
#
#                                             userImage  \
# 20  https://play-lh.googleusercontent.com/a-/ALV-U...
# 19  https://play-lh.googleusercontent.com/a-/ALV-U...
# 15  https://play-lh.googleusercontent.com/a-/ALV-U...
# 14  https://play-lh.googleusercontent.com/a/ACg8oc...
# 40  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                               content  score  thumbsUpCount  \
# 20  Aplikasi threads ini merupakan aplikasi yang m...      5              0
# 19  Sebenarnya sudah bagus, sayang fitur seperti h...      4              3
# 15  Threads gk ramah kayak dulu, padahal baru buka...      1              3
# 14  Aplikasi nya gak bisa dibuka , cuman bisa liat...      1              3
# 40  Tambahin fitur translet bahasa dong. Bagi saya...      5              1
#
#    reviewCreatedVersion                  at replyContent repliedAt  \
# 20       301.0.0.30.109 2023-09-30 21:35:21         None      None
# 19       299.0.0.34.109 2023-09-12 20:04:50         None      None
# 15       299.0.0.34.109 2023-09-12 15:41:35         None      None
# 14       299.0.0.34.109 2023-09-09 14:59:06         None      None
# 40       293.0.0.30.110 2023-08-05 21:55:21         None      None
#
#         appVersion
# 20  301.0.0.30.109
# 19  299.0.0.34.109
# 15  299.0.0.34.109
# 14  299.0.0.34.109
# 40  293.0.0.30.110

# %%
# my_df = sorted_df[['userName', 'score','at', 'content']] #get userName, rating, date-time, and reviews only

# %%
# my_df = sorted_df.head()

# %%
sorted_df.to_csv("scrapped_data.csv", index = False)  #Save the file as CSV , to download: click the folder icon on the left. the csv file should be there.

# %%
df = pd.read_csv('scrapped_data.csv')
df.shape
# Out:
# (100, 11)

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from collections import defaultdict
from textwrap import wrap

# # Torch ML libraries
# import transformers
# from transformers import BertModel, BertTokenizer, AdamW get_linear_schedule_with_warmup
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader

# Misc.
import warnings
warnings.filterwarnings('ignore')

# %%
# Set intial variables and constants
# %config InlineBackend.figure_format='retina'

# Graph Designs
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8

# Random seed for reproducibilty
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

# Set GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Let's have a look at the class balance.
sns.countplot(df.score)
plt.xlabel('review score')
# Out:
# Text(0.5, 0, 'review score')
